# %% [markdown]
# # Downloading and Installing the Model

# %%
# !ls
# Out:
# Cleaning and Preparing News Data.ipynb
# Exploring Keras.ipynb
# GPT2-Model-Fakes
# Generating Fake News with Grover.ipynb
# Grover-Fakes
# Keras_Model
# NEURAL FAKES TEST.ipynb
# News-DataSet
# Notebooks
# README.md
# Screen Shot 2021-05-11 at 9.26.19 PM.png
# Topic Modeling.ipynb
# Totally-Real-News
# Visualization Dashboards
# best_model
# best_model2.h5
# fake_text_news_lda.html
# grover
# models
# src

# %%
# !python --version
# Out:
# Python 3.7.0

# %%
conda install python=3.7.0
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistenc/
#
#   - defaults/osx-64::anaconda==2020.11=py38_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/javiercabrera/opt/anaconda3
#
#   added / updated specs:
#     - python=3.7.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-5.3.1    |           py37_0           6 KB
#     _ipyw_jlab_nb_ext_conf-0.1.0|           py37_0           4 KB
#     anaconda-custom            |           py37_1           3 KB
#     anaconda-client-1.7.2      |     pyhd8ed1ab_1          70 KB  conda-forge
#     anaconda-navigator-2.0.3   |           py37_0         6.3 MB
# ...

# %%
pip install tensorflow==1.14
# Out:
# ...
#      |████████████████████████████████| 105.8 MB 78 kB/s s eta 0:00:01  |                                | 327 kB 1.3 MB/s eta 0:01:19     |███████████████████▉            | 65.4 MB 13.9 MB/s eta 0:00:03     |████████████████████▋           | 68.2 MB 13.9 MB/s eta 0:00:03
# ...
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# ...
#      |████████████████████████████████| 488 kB 15.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 959 kB 22.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 25.0 MB/s eta 0:00:01
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# ...
#      |████████████████████████████████| 3.9 MB 24.2 MB/s eta 0:00:01
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# ...

# %%
# !pip install gpt-2-simple
# Out:
# ...
#   Using cached gpt_2_simple-0.7.2.tar.gz (25 kB)
# ...
#   Using cached toposort-1.6-py2.py3-none-any.whl (9.5 kB)
# ...
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.2-py3-none-any.whl size=23619 sha256=0e58b7e95200d042ec77edec93c42b055dd0da46bc61d11e17ff4555def8b2e8
#   Stored in directory: /Users/javiercabrera/Library/Caches/pip/wheels/f8/a0/0b/18b541426b0d966b55ae6dc35628a85f67d0698e5fabb1d6c7
# Successfully built gpt-2-simple
# ...

# %%
import tensorflow
# Out:
# /Users/javiercabrera/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/javiercabrera/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/javiercabrera/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tensorflow.__version__
# Out:
# '1.14.0'

# %%
import gpt_2_simple as gpt2
from datetime import datetime

# %%
model_path = './GPT2-Model-Fakes/checkpoint_run3.tar'

# %%
sess = gpt2.start_tf_sess()

# %%
ls
# Out:
# Cleaning and Preparing News Data.ipynb
# Exploring Keras.ipynb
# GPT2-Model-Fakes/
# Generating Fake News with Grover.ipynb
# Grover-Fakes/
# Keras_Model/
# NEURAL FAKES TEST.ipynb
# News-DataSet/
# Notebooks/
# README.md
# Screen Shot 2021-05-11 at 9.26.19 PM.png
# Topic Modeling.ipynb
# Totally-Real-News/
# Visualization Dashboards/
# best_model/
# best_model2.h5
# fake_text_news_lda.html
# grover/
# models/
# src/

# %%
gpt2.load_gpt2(sess, run_name = 'run3', model_dir = 'GPT2-Model-Fakes', checkpoint_dir = './GPT2-Model-Fakes/checkpoint')
# Out:
# Loading checkpoint ./GPT2-Model-Fakes/checkpoint/run3/model-450
# WARNING:tensorflow:From /Users/javiercabrera/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./GPT2-Model-Fakes/checkpoint/run3/model-450

# %%
def generatefakes(length, temperature, prefix, nsamples):
    '''
    length: Number of tokens to generate (default 1023, the maximum)
    temperature: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
    top_k: Limits the generated guesses to the top k guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set top_k=40)
    top_p: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with top_p=0.9)
    truncate: Truncates the input text until a given sequence, excluding that sequence (e.g. if truncate='<|endoftext|>', the returned text will include everything before the first <|endoftext|>). It may be useful to combine this with a smaller length if the input texts are short.
    include_prefix: If using truncate and include_prefix=False, the specified prefix will not be included in the returned text.
    nsamples: how many samples you want to generate
    prefix: How you want the sentence to start

    '''
    return gpt2.generate(sess,
              length=length,
              top_k = 5,
              temperature=temperature,
              prefix=prefix,
              nsamples=nsamples,
              batch_size=nsamples,
              run_name='run3',
              checkpoint_dir ='./GPT2-Model-Fakes/checkpoint', top_p = 0.9)

# %%
top_p = .9
generatefakes(200, .8, 'Biden is part of the KKK', 1,)
# Out:
# Biden is part of the KKK, too — so his record on this issue is not particularly surprising.
#
# But this is different. Weaned on the image of Teddy Roosevelt, Obama's southern redoubt heritage now makes him attractive to voters of all political persuasions. He will connect with many on the conservative side of the aisle; he will be a valuable dialecticum for taking a look at the state of the union message after midnight Wednesday.
#
# And because of the nature of the election, there are two paths. Republican strategists are hoping that by pushing harder than Democrats will be able to to obstructionist Obama, they can convince some on the Democratic side that they are the better option.
#
# If not Obama, then somebody in the White House. If not somebody in the CIA, then somebody in the FBI. There's no question that someone in the Obama White House is the better choice.
#
# Based on my conversations with a number of people within the White House, one thing is certain
